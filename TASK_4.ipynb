# %% [markdown]
# # Day 4 – Pandas Basics
#
# ## Objective
#
# Learn the fundamentals of Pandas by loading a CSV dataset and exploring its structure.
#
# ## Topics Covered
#
# - Importing Pandas
# - Loading CSV Files
# - Viewing Dataset
# - First & Last Rows
# - Dataset Information
# - Shape
# - Columns
# - Data Types
# - Summary Statistics
# - Missing Values
# - Filtering Data
# - Sorting Data
# - Value Counts
#
# ## Technologies
#
# - Python
# - Pandas
# - Google Colab
#
# ## Dataset
#
# student_data.csv
#
# ## Run
#
# 1. Open Google Colab
# 2. Upload `student_data.csv`
# 3. Run all notebook cells
#
# ## Learning Outcome
#
# - Successfully loaded a CSV dataset
# - Explored rows and columns
# - Retrieved dataset information
# - Performed basic data analysis using Pandas
#
# ## Author
#
# **Shwetaparna dash**
# Data Science Intern
# Codomax Digital Solutions

# %% [markdown]
# TASK-4

# %% [markdown]
# Import Pandas

# %%
import pandas as pd

print("Pandas Version:", pd.__version__)
# Out:
# Pandas Version: 2.2.2

# %% [markdown]
# Upload CSV File

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-c9322126-6c30-459f-9e2f-9844ee40d423" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c9322126-6c30-459f-9e2f-9844ee40d423">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Load Dataset

# %%
df = pd.read_csv("student_data.csv")

print("Dataset Loaded Successfully!")
# Out:
# Dataset Loaded Successfully!

# %% [markdown]
# Display Dataset

# %%
df
# Out:
#     Student_ID      Name  Age  Gender                   Course  Marks  \
# 0          101    Gopal    21    Male             Data Science     96
# 1          102    Shweta   21  Female         Machine Learning     94
# 2          103       Anu   20  Female             Data Science     88
# 3          104      Hari   21    Male         Machine Learning     92
# 4          105     Kiran   19    Male                   Python     79
# 5          106     Diana   22  Female  Artificial Intelligence     95
# 6          107     Ethan   20    Male             Data Science     84
# 7          108     Fiona   21  Female                   Python     90
# 8          109    George   23    Male         Machine Learning     87
# 9          110    Hannah   20  Female           Data Analytics     91
# 10         111       Ian   22    Male  Artificial Intelligence     85
# 11         112     Julia   21  Female             Data Science     93
# ...

# %% [markdown]
# First Five Rows

# %%
df.head()
# Out:
#    Student_ID    Name  Age  Gender            Course  Marks         City
# 0         101  Gopal    21    Male      Data Science     96  Bhubaneswar
# 1         102  Shweta   21  Female  Machine Learning     94      Cuttack
# 2         103     Anu   20  Female      Data Science     88     New York
# 3         104    Hari   21    Male  Machine Learning     92      Chicago
# 4         105   Kiran   19    Male            Python     79      Houston

# %% [markdown]
# Last Five Rows

# %%
df.tail()
# Out:
#     Student_ID    Name  Age  Gender                   Course  Marks  \
# 45         146  Simran   22  Female           Data Analytics     91
# 46         147   Harsh   20    Male  Artificial Intelligence     88
# 47         148   Aisha   21  Female         Machine Learning     94
# 48         149  Nikhil   22    Male             Data Science     87
# 49         150    Diya   20  Female                   Python     92
#
#                   City
# 45          Chandigarh
# 46              Ranchi
# 47  Thiruvananthapuram
# 48              Mysuru
# 49            Vadodara

# %% [markdown]
# Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  50 non-null     int64
#  1   Name        50 non-null     object
#  2   Age         50 non-null     int64
#  3   Gender      50 non-null     object
#  4   Course      50 non-null     object
#  5   Marks       50 non-null     int64
#  6   City        50 non-null     object
# dtypes: int64(3), object(4)
# memory usage: 2.9+ KB

# %% [markdown]
# Dataset Shape

# %%
print("Rows and Columns:", df.shape)
# Out:
# Rows and Columns: (50, 7)

# %% [markdown]
# Column Names

# %%
print(df.columns)
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Gender', 'Course', 'Marks', 'City'], dtype='object')

# %% [markdown]
# Data Types

# %%
print(df.dtypes)
# Out:
# Student_ID     int64
# Name          object
# Age            int64
# Gender        object
# Course        object
# Marks          int64
# City          object
# dtype: object

# %% [markdown]
# Statistical Summary

# %%
df.describe()
# Out:
#        Student_ID       Age      Marks
# count    50.00000  50.00000  50.000000
# mean    125.50000  21.00000  88.680000
# std      14.57738   0.92582   4.381967
# min     101.00000  19.00000  79.000000
# 25%     113.25000  20.00000  86.000000
# 50%     125.50000  21.00000  89.000000
# 75%     137.75000  22.00000  92.000000
# max     150.00000  23.00000  96.000000

# %% [markdown]
# Check Missing Values

# %%
df.isnull().sum()
# Out:
# Student_ID    0
# Name          0
# Age           0
# Gender        0
# Course        0
# Marks         0
# City          0
# dtype: int64

# %% [markdown]
# Display Specific Columns

# %%
df[["Name","Course","Marks"]]
# Out:
#         Name                   Course  Marks
# 0     Gopal              Data Science     96
# 1     Shweta         Machine Learning     94
# 2        Anu             Data Science     88
# 3       Hari         Machine Learning     92
# 4      Kiran                   Python     79
# 5      Diana  Artificial Intelligence     95
# 6      Ethan             Data Science     84
# 7      Fiona                   Python     90
# 8     George         Machine Learning     87
# 9     Hannah           Data Analytics     91
# 10       Ian  Artificial Intelligence     85
# 11     Julia             Data Science     93
# 12     Kevin                   Python     81
# 13     Laura         Machine Learning     89
# 14   Michael             Data Science     86
# 15     Nancy           Data Analytics     90
# 16    Oliver  Artificial Intelligence     94
# 17  Patricia                   Python     88
# 18   Quentin         Machine Learning     83
# 19    Rachel             Data Science     91
# ...

# %% [markdown]
# Students with Marks Above 90

# %%
high_marks = df[df["Marks"] > 90]

high_marks
# Out:
#     Student_ID      Name  Age  Gender                   Course  Marks  \
# 0          101    Gopal    21    Male             Data Science     96
# 1          102    Shweta   21  Female         Machine Learning     94
# 3          104      Hari   21    Male         Machine Learning     92
# 5          106     Diana   22  Female  Artificial Intelligence     95
# 9          110    Hannah   20  Female           Data Analytics     91
# 11         112     Julia   21  Female             Data Science     93
# 16         117    Oliver   23    Male  Artificial Intelligence     94
# 19         120    Rachel   20  Female             Data Science     91
# 21         122      Tina   22  Female                   Python     92
# 23         124  Victoria   21  Female         Machine Learning     95
# 26         127      Yash   21    Male  Artificial Intelligence     93
# 29         130    Ananya   21  Female             Data Science     91
# ...

# %% [markdown]
# Average Marks

# %%
print("Average Marks:", df["Marks"].mean())
# Out:
# Average Marks: 88.68

# %% [markdown]
# Maximum & Minimum Marks

# %%
print("Highest Marks:", df["Marks"].max())
print("Lowest Marks:", df["Marks"].min())
# Out:
# Highest Marks: 96
# Lowest Marks: 79

# %% [markdown]
# Sort by Marks

# %%
df.sort_values(by="Marks", ascending=False)
# Out:
#     Student_ID      Name  Age  Gender                   Course  Marks  \
# 0          101    Gopal    21    Male             Data Science     96
# 5          106     Diana   22  Female  Artificial Intelligence     95
# 39         140     Kavya   22  Female             Data Science     95
# 23         124  Victoria   21  Female         Machine Learning     95
# 1          102    Shweta   21  Female         Machine Learning     94
# 16         117    Oliver   23    Male  Artificial Intelligence     94
# 31         132     Priya   20  Female  Artificial Intelligence     94
# 47         148     Aisha   21  Female         Machine Learning     94
# 11         112     Julia   21  Female             Data Science     93
# 26         127      Yash   21    Male  Artificial Intelligence     93
# 41         142    Ishita   21  Female  Artificial Intelligence     93
# 36         137     Rahul   22    Male  Artificial Intelligence     92
# ...

# %% [markdown]
# Course-wise Student Count

# %%
df["Course"].value_counts()
# Out:
# Course
# Data Science               12
# Machine Learning           11
# Python                     11
# Artificial Intelligence     9
# Data Analytics              7
# Name: count, dtype: int64

# %% [markdown]
# Final Output

# %%
print("="*60)
print("Day 4 Task Completed Successfully")
print("Pandas Basics")
print("Dataset Loaded and Analyzed Successfully")
print("Organization : Codomax Digital Solutions")
print("="*60)
# Out:
# ...
# Day 4 Task Completed Successfully
# Pandas Basics
# Dataset Loaded and Analyzed Successfully
# Organization : Codomax Digital Solutions
# ...
